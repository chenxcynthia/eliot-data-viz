# %%
import csv
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="cynthia-app")

# %%
location = geolocator.geocode("175 5th Avenue NYC")
print(location.latitude)

# %%
df['latitude'] = df.apply(lambda row: geolocator.geocode(row['hometown']).latitude, axis = 1)

# %%
df['longitude'] = df.apply(lambda row: geolocator.geocode(row['hometown']).longitude, axis = 1)

# %%
len(df)
# Out:
# 37

# %%
# create id dict
id_to_name = {}

for i in range(len(df)):
    id_to_name[df.iloc[i]['name'].strip(' ')] = i

# %%
id_to_name
# Out:
# {'Dylan Wilson': 0,
#  'Luke Tomes': 1,
#  'Cynthia Chen': 2,
#  'Karley Merkley': 3,
#  'Sarah Mrad': 4,
#  'Audrey Gunawan': 5,
#  'Robin Robinson ': 6,
#  'Kira Nagoshi': 7,
#  'Saylor Willauer': 8,
#  'Lily Roberts': 9,
#  'Maycee Wieczorek ': 10,
#  'Tina Gong': 11,
#  'Matthew Andrews': 12,
#  'Siena Lerner-Gill': 13,
#  'Karen Li': 14,
#  'Ellen Hwang': 15,
#  'Jillian Graver': 16,
#  'Chibuike Uwakwe': 17,
#  'Bobby Current': 18,
#  'Anna Correll': 19,
#  'Evangeline Liao': 20,
#  'Michael Wu': 21,
#  'Afiya Quryshi': 22,
#  'Sam Cohen': 23,
#  'SeoYoung Ha': 24,
#  'Audrey Ory': 25,
#  'Evan Jiang': 26,
#  'Rohan Shah': 27,
#  'Anais Colin': 28,
#  'Alison Chen': 29,
#  'Will Schrepferman': 30,
#  'Riley Kunz': 31,
#  'Hannah Gadway': 32,
#  'Griffin Wong': 33,
#  'Ashley Zhuang': 34,
#  'Andrew Honold': 35,
#  'Heavyn Lee': 36,
#  'James Chen': 37,
#  'Rohan Rajeev': 38,
#  'Grayson Martin': 39,
#  'Drake Evan Johnson': 40,
#  'Eura Choi': 41,
#  'Shannon Hollands': 42,
#  'Madison Shirazi': 43,
#  'Emily Nguyen': 44,
#  'Alina Taratorin': 45,
#  'Ashton Body': 46,
#  'Delaney Jones': 47,
#  'Claire Duncan': 48,
#  'Mairead Baker': 49,
#  'Tilly Krishna': 50,
#  'Zoe Goldstein': 51,
#  'Ayana Gray': 52,
#  'Zory Montemayor': 53,
#  'Philip Brinn': 54,
#  'Isileli Kakala': 55,
#  'Stephanie Kaiser': 56,
#  'Dora Paolini': 57,
#  'Henry Austin': 58,
#  'Christian Abney': 59,
#  'Juan Molina': 60,
#  'Camille Dash': 61,
#  'Maddie Dowd': 62,
#  'Genevieve Raushenbush': 63,
#  'Celia Silver': 64,
#  'Maycee Wieczorek': 65,
#  'Grace Carlson': 66,
#  'Addie Esposito': 67,
#  'Genevieve Rauschenbusch': 68,
#  'Huiwen Chen': 69,
#  'Karen Choi': 70,
#  'Misha Nair': 71,
#  'Hewan Kidanemariam': 72,
#  'David Dylan Wilson': 73,
#  'Grayson Macalister Martin': 74,
#  'Noelle Chung': 75,
#  'Ashley Lee': 76,
#  'Rhea Acharya': 77,
#  'Cassia Lee': 78,
#  'Mariam Kush': 79,
#  'Jesus Gomez': 80,
#  'Unique Hodge': 81,
#  'Ella Eisenberg': 82,
#  'Lauren Marshall': 83,
#  'Alyssa Klee': 84,
#  'Veronica Cyzewski': 85,
#  'Olivia Morris': 86,
#  'Prasidh Chhabria': 87,
#  'Elynna Chang': 88,
#  'Josh Chiang': 89,
#  'Joseph Lee.': 90,
#  'Benjamin Hogewood': 91,
#  'Israel Perez': 92,
#  'Ezechukwu Nduka': 93,
#  'Brian Ibeabuchi': 94,
#  'Isaiah Coleman': 95,
#  'David Hill': 96,
#  'Chinaza Agbim': 97,
#  'Fianko Buckle': 98,
#  'Aiden Aguirre': 99,
#  'Yanni Raymond': 100,
#  'Aldo Medina': 101,
#  'Daniel Son': 102,
#  'Finn Bamber': 103,
#  'Erin Aslami': 104,
#  'Jordan Mubako': 105,
#  'Djibril Rushingabigwi': 106,
#  'Jonathan Yuan': 107,
#  'Vivien Tran': 108,
#  'Evelyn Manyatta': 109,
#  'Daniella Ineza': 110,
#  'Harper Oreck': 111,
#  'Christian Browder': 112,
#  'Sun-Jung Yum': 113,
#  'Daniel Kwon': 114,
#  'Racheal Lama': 115,
#  'Sky Jung': 116,
#  'Pichamon Assawaphadungsit': 117,
#  'Evelyn Ma': 118,
#  'Dhiya Sani': 119,
#  'Sarah Mann': 120,
#  'Renee Ferguson': 121,
#  'Aubrienne Bell': 122,
#  'Saskia Fisher': 123,
#  'Adam Mohamed': 124,
#  'Kevin Wang': 125,
#  'Henry Xuan': 126,
#  'Aden Barton': 127,
#  'Roman Ugarte': 128,
#  'Charlie Steinbaum': 129,
#  'McGavock Cooper': 130,
#  'Alex Rodriguez': 131,
#  'Kerry Daley': 132,
#  'Matthew Cabot': 133,
#  'Declan Buckley': 134,
#  'Julia Sperling': 135,
#  'Tenzin Dadak': 136,
#  'Helen Scarborough': 137,
#  'Nidhi Patel': 138,
#  'Oscar Berry': 139,
#  'Emmet Halm': 140,
#  'Chibby Uwakwe': 141,
#  'Mohamed Mabizari': 142,
#  'Ben Hogewood': 143,
#  'Izzy Perez': 144,
#  'Mubeen Momodu': 145,
#  'Eze Nduka': 146,
#  'Garrett Sharp': 147,
#  'Jake Lugg': 148,
#  'Jake Rizy': 149,
#  'Thor Griffith': 150,
#  'Yanyan Zeng': 151,
#  'Jessica Zhang': 152,
#  'Mina Barac': 153,
#  'Ellie Wiesler': 154,
#  'Victor Goncalves': 155,
#  'Guillermo Rodriguez': 156,
#  'Jordan Woods': 157,
#  'Ishaan Modi': 158,
#  'Andrew Zhang': 159,
#  'Raymond Huang': 160,
#  'Hana Lang': 161,
#  'Samuel Dvorak': 162,
#  'Kilee Mercedes': 163,
#  'Johnny Sedano': 164,
#  'Ebony Smith': 165,
#  'Justin Hill': 166,
#  'Brice Austin': 167,
#  'Sean Fallon': 168,
#  'Kaleb Archer': 169,
#  'Josh Zhu': 170,
#  'Paul Hegarty': 171,
#  'Sue Weltman': 172,
#  'Katherine Hodakowski': 173,
#  'Nathan Wu': 174,
#  'Hannah Davis': 175,
#  'Emmett Kistler': 176,
#  'Zach Mecca': 177,
#  'Ryan McCarthy': 178,
#  'Alex Klein Wassink': 179,
#  'Ben Weatherwax': 180,
#  'Alex Petty': 181,
#  'Marcus Holmquist': 182,
#  'Cole Kuster': 183,
#  'Clare Duncan': 184,
#  'Seo Young Ha': 185,
#  'Diana Zhu': 186,
#  'Kathryn Zhou': 187,
#  'Bridget Sands': 188,
#  'Saylor Williams': 189,
#  'Aika Aldayarova': 190,
#  'Marwan Uwaydah': 191,
#  'Kiani Akina': 192,
#  'Raquel Aguirre': 193,
#  'Edona Cosovic': 194,
#  'Ray Chen': 195,
#  'Nathaniel Wu': 196,
#  'Troy Powell': 197,
#  'Brian Baltazar': 198,
#  'Yana Hubyak': 199,
#  'Alisa Regassa': 200,
#  'Gunnhildur': 201,
#  'Ezechukwu': 202,
#  'Gabby David': 203,
#  'Austin Li': 204,
#  'Garrett Sharpe': 205,
#  'Caroline Bukowski': 206,
#  'Abigail Cusick': 207,
#  'Mattheus Carpenter': 208,
#  'Tatiana Miranda': 209,
#  'Felix Chen': 210,
#  'Laura Connor': 211,
#  'Owen Ebose': 212,
#  'Harold Klapper': 213,
#  'Michael Frim': 214,
#  'Aweys Abdullatif': 215,
#  'Karley Hou': 216,
#  'Austin Kaufman': 217,
#  'Jack Shaw': 218,
#  'Giulia Mazzarelli': 219,
#  'Sara Moore': 220,
#  'Omar Sotelo': 221,
#  'Carter Stewart': 222,
#  'Robin Robinson': 223,
#  'Zoe Goldberg': 224,
#  'Abby Cusick': 225,
#  'Victoria Wijerathnayapa': 226,
#  'Connor Riordan': 227,
#  'Kaija Hornberg': 228,
#  'Taj Gulati': 229,
#  'Sol Gutierrez': 230,
#  'Yaying Li': 231,
#  'Dhamar': 232,
#  'Alexander Park': 233,
#  'Eliot Min': 234,
#  'Mihir Gowda': 235,
#  'Luke Tome': 236,
#  'Dash Chin': 237,
#  'Chris Lee': 238,
#  'Alex Zhou': 239,
#  'Nico Vallenas': 240,
#  'Jack Fetsch': 241,
#  'Sherry Liu': 242,
#  'Adam Reid': 243,
#  'Nick Laws': 244,
#  'Christina Zhao': 245,
#  'Kayla Huang': 246,
#  'Jamie Lu': 247,
#  'Jara Emtage-Cave': 248,
#  'Elizabeth Yang': 249,
#  'Guillermo Aldino Guzmann Avarro': 250,
#  'Sailor Williamson': 251,
#  'Helen Xiao': 252,
#  'Elizabeth Zhong': 253,
#  'Vivian Nguyen': 254,
#  'Jessica Liu': 255,
#  'Sayak Maity': 256,
#  'Karly Hou': 257,
#  'Brandon Won': 258,
#  'Ibraheem Khan': 259,
#  'Danu Mudannayake': 260,
#  'Clair Fu': 261,
#  'Oliver Wolf': 262,
#  'Ebony Smith Brock Lockinar': 263,
#  'Joseph Alexander': 264,
#  'Christian Wagner': 265,
#  "Da'Vion Tatum": 266,
#  'Aaron Bradford': 267,
#  'Ava Baldassari': 268,
#  'Alexandra Topic': 269,
#  'Chris Wirth': 270,
#  'David Paquette': 271,
#  'Emily Tsai': 272,
#  'Ibrahim Ibrahim': 273,
#  'Izzy Kakala': 274,
#  'Jonas Hansen': 275,
#  'Lexie Purcell': 276,
#  'Marissa Li': 277,
#  'Noah Brune': 278,
#  'Olivia Wenzel': 279,
#  'Rajat Mittal': 280,
#  'Alex Park': 281,
#  'Andrew LaScaleia': 282,
#  'Anil Bradley': 283,
#  'Brittany Sun': 284,
#  'Finley Ong': 285,
#  'Gabriella Kennedy': 286,
#  'Gary Kane': 287,
#  'Mark Pekala': 288,
#  'Ryosuke Takashi': 289,
#  'Alycia Cary': 290,
#  'Elizabeth Roosevelt': 291,
#  'Julia Montgomery': 292,
#  'Stephanie Lin': 293,
#  'Aseelah Ashraf': 294,
#  'Namirah Quadir': 295,
#  'Christina Xiao': 296,
#  'Nico Barlos': 297,
#  'Sofia Perez Casillas': 298,
#  'Gabriella Kennealy': 299,
#  'Anaïs Colin': 300,
#  'Nini Baghashvili': 301,
#  'Jeremiah Kim': 302,
#  'Jack Kelly': 303,
#  'Michael Montella': 304,
#  'Roy Han': 305,
#  'Elias Schisgall': 306,
#  'Kate Vandermel': 307,
#  'Amelie': 308,
#  'Ella Rescigno': 309,
#  'Alex Kleinwassink': 310,
#  'Kathryn Hodakowski': 311,
#  'Kwaku Adubofour': 312,
#  'Gianna Zades': 313,
#  'Louis Mukama': 314,
#  'Amal Mattoo': 315,
#  'Esther Plotnick': 316,
#  'Anne Lheem': 317,
#  'Anca Dragulescu': 318,
#  'Clarence Chan': 319,
#  'Irene Kim': 320,
#  'Rachel Phan': 321,
#  'Emily Zhu': 322,
#  'Kelsey Ichikawa': 323,
#  'Robert Jomar Malate': 324,
#  'Rahul Subramaniam': 325,
#  'Sam Dvorak': 326,
#  'Lourdes Vivanco': 327,
#  'Leonard Tang': 328,
#  'Andrea Lamas-Nino': 329,
#  'AJ Yi': 330,
#  'Vincent Pan': 331,
#  'Ramiz Razzak': 332,
#  'Shrey Sharma': 333,
#  'Romil Sirohi': 334,
#  'Emmy Cho': 335,
#  "and tutors of course! (Plus more I may have forgotten - I made most of my friends in Eliot! Even some who weren't Eliotites - not sure if you want me to include those though.)": 336,
#  'Genesis Nam': 337,
#  'Kathy Zhong': 338,
#  'Jackelyn Baldwin': 339,
#  'Angelica Carrillo': 340,
#  'Matylda Urbaniak': 341,
#  'Arba Shkreli': 342,
#  'Zev Shapiro': 343,
#  'Lauren Baehr': 344,
#  'Cynthia Chen (hi Cynthia!!)': 345,
#  'Neo Guerrero': 346,
#  'Jack Boettcher': 347,
#  'Lauren Kim': 348,
#  'Kaede Ishidate': 349,
#  'Ammaar Saeed': 350,
#  'Sajeev Kohli': 351,
#  'Sirina Prasad': 352,
#  'Ava Salzman': 353,
#  'Kai Ford': 354,
#  'Naomi Hegwood': 355,
#  'Vassilios Kaxiras': 356,
#  'Alexa Zinke': 357,
#  'Sam Maroshick': 358,
#  'Courtney Rabb': 359,
#  'Solomina Darko': 360,
#  'Daphnée Piou': 361,
#  'Chelsea Williams': 362,
#  'Jillian Wachira': 363,
#  'Xaviera Zime': 364,
#  'Bhargavi Garimella': 365,
#  'Kashish Bastola': 366,
#  'Alisa Rega': 367,
#  'Logan Clifton': 368,
#  'Victor Gonçalves': 369,
#  'Ife Omidiran': 370,
#  'Jackie Okereke': 371,
#  'Emma Oyakhire': 372,
#  'Sameerah Lawal': 373,
#  'Joelle Williams': 374,
#  'Akua Pokuaah': 375,
#  'Dekyus Dickerson': 376,
#  'Raphael Tsiamis': 377,
#  'Olivia Jochl': 378,
#  'Drake Johnson': 379,
#  'Beck Saine': 380,
#  'Alex Wassink': 381,
#  'Sophia Salamanca': 382,
#  'Cybèle Fasquelle': 383}

# %%
type('s')
# Out:
# str

# %%
for i in range(len(df)):
    s = df.iloc[i]['roommates']
    if type(s) != str: continue
    s = s.replace('\n', ', ')
    split_list = s.split(', ')
    roommates_list = []
    for s in split_list:
        cleaned_name = s.strip(',').strip(' ')
        if cleaned_name not in id_to_name:
            id_to_name[cleaned_name] = len(id_to_name)
        roommates_list.append(cleaned_name)
        
    s = df.iloc[i]['people']
    if type(s) != str: continue
    s = s.replace('\n', ', ')
    split_list = s.split(', ')
    people_list = []
    for s in split_list:
        cleaned_name = s.strip(',').strip(' ')
        if cleaned_name not in id_to_name:
            id_to_name[cleaned_name] = len(id_to_name)
        people_list.append(cleaned_name)
